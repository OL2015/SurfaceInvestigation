# %%
def ShowImage(data):
    import matplotlib.pyplot as plt
    plt.imshow(data,cmap=plt.get_cmap('gray'), vmin=0, vmax=1)
    display.display(plt.gcf())
pass

# %%
import numpy as np  
import os
import Image2D
from IPython import display
reload(Image2D)
img2d = Image2D.Image2D(600,800,150)
img2d.ImageTwoBowl()
ShowImage(img2d.image)

# %%
img2d.BlurFilter(20,5)
ShowImage(img2d.image)

# %%
img2d.AddGradient(0.0001,0.00005,-0.01)
ShowImage(img2d.image)
img2d.SaveImage('result.bmp')

# %%
#img2d.AddShadow(0,0)
#ShowImage(img2d.image)
